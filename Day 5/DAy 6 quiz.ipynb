# %% [markdown]
# # File System Commands Quiz
#
# ## Question 1
#
# Which command syntax is correct if you want to assign read-only permission to everyone and write permission to the owner of the file?
#
# - `chmod atr u+w filename`
# - `chmod atr filename`
# - `chmod u+w filename`
# - `chmod atw filename`
# - `chmod utr filename`
# - `chmod gtr filename`
# - `chmod utw filename`
#
# ## Question 2
#
# Which command is used to change file ownership?
#
# - `chowner`
# - `chgrp`
# - `chmod`
# - `chown`
#
# ## Question 3
#
# Why do we need pipes?
#
# - To connect user with a new command
# - To further process the input of the preceding command
# - To further process the output of the preceding command
# - To join two files
#
# ## Question 4
#
# List 3 basic commands of file navigation?
#
# - `ls, pwd, cd`
# - `ls, pwd, chmod`
# - `pipe, pwd, cd`
# - `ls, chgrp, cd`
#
# ## Question 5
#
# Which command is used to remove a directory?
#
# - `rm -r DIRECTORYNAME`
# - `rm DIRECTORYNAME`
# - `mv -r DIRECTORYNAME`
# - `rm -i DIRECTORYNAME`
#
# ## Question 6
#
# Which command is used to change group ownership of a file?
#
# - `chgrp`
# - `chgroup`
# - `chown`
# - `chmod`
#
# ## Question 7
#
# What are the different ways to view a file?
#
# - `cat`
# - `vi`
# - `more`
# - `less`
# - All of the above
#
# ## Question 8
#
# How to rename a file?
#
# - `rename`
# - `mv`
# - `rm`
# - `chown`
#
# ## Question 9
#
# Which command is used to search for a keyword or pattern in a file?
#
# - `awk`
# - `sort`
# - `grep`
# - `echo`
#
# ## Question 10
#
# What is the purpose of the `sort` command?
#
# - It cuts the file in half
# - It sorts the output of a command
# - It sorts the output of a file
# - None of the above
# - B and C
# - A and C
#
# ## Question 11
#
# Why do we need to use `help` or `man` commands?
#
# - It helps us remember the commands
# - It helps us remember the command options
# - It helps us remember the purpose of a command and its options
# - Help commands are useful to list directory contents
# - All of the above
#
# ## Question 12
#
# What happens when you run the following command: `echo "Today is Sunday" >> testfile`?
#
# - It overwrites testfile with "Today is Sunday"
# - It appends testfile with "Today is Sunday"
# - It deletes the testfile and re-creates a new file with a name "Today is Sunday"
# - It adds to the top of testfile
#
# ## Question 13
#
# Which of the following is used to add read and write permission to the owner and group of the `source.txt` file?
#
# - `chmod a+rw source.txt`
# - `chmod ug+rw source.txt`
# - `chmod source.txt ug+rw`
# - `chmod ug+rx source.txt`
#
# ## Question 14
#
# What is the output of the command `wc -l file.txt` if the file contents are:
#
# - firstline
# - secondline
# - thirdline
# - fourthline
#
# options
# - `4 file.txt`
# - `5 file.txt`
# - `6 file.txt`
# - `8 file.txt`
#
# ## Question 15
#
# There are 10 lines in a file, how do you print lines between 6 and 9 (all inclusive)?
#
# - `cat somefile.txt | tail -5 | head -4`
# - `cat somefile.txt | tail -6 | head -4`
# - `cat somefile.txt | head -6 | head -2`
# - `cat somefile.txt | tail -4 | head -4`
