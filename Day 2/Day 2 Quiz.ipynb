# %% [markdown]
# # VirtualBox and Linux Fundamentals Quiz
#
# This document contains a series of questions related to Oracle VirtualBox, Linux distributions, and general virtualization concepts. Each question is followed by a set of possible answers.
#
# ## Question 1: What is VirtualBox?
#
# 1. It is pre-configured at the hardware level
# 2. It is installed on top of an operating system for applications to share resources
# 3. It is installed on top of an operating system to run multiple operating systems and share resources
# 4. It allows us to run only MAC on a Windows PC
#
# ## Question 2: How to install Oracle VirtualBox on your computer?
#
# 1. Go to virtualbox.edu, go down to "VirtualBox platform packages", select the package based on your operating system, download and install
# 2. Download the ISO image and execute it
# 3. Go to virtualbox.org, go down to "VirtualBox platform packages", select the package based on your operating system, download and install
# 4. All of the above
#
# ## Question 3: Which of the following are Linux distributions?
#
# 1. CentOS, Redhat, SUSE
# 2. Windows, CentOS, Redhat, SUSE
# 3. CentOS, Redhat, SUSE, Debian, Ubuntu, MAC
# 4. CentOS, Redhat, SUSE and VMWare
#
# ## Question 4: A virtual machine can run which of the following?
#
# 1. Operating system
# 2. Database
# 3. Application
# 4. Storage
#
# ## Question 5: What is Linux Open Source?
#
# 1. It cannot be copied
# 2. It cannot be replicated
# 3. The programming source code is available and cannot be editable
# 4. The programming source code is available which can be copied and then it can be editable
#
# ## Question 6: The Linux installation wizard asks you the following questions:
#
# 1. Language, Hostname, Network, Packages, File partition, root password
# 2. Language, Hostname, and the number of employees
# 3. Language, Hostname, Network, Packages, File partition, and RAID
# 4. All of the above
#
# ## Question 7: What are the different ways to install an Operating system?
#
# 1. ISO image
# 2. Disc
# 3. Network install
# 4. All of the above
#
# ## Question 8: Which of the following is NOT true regarding VMware Player and Oracle VirtualBox?
#
# 1. They both allow you to run a "virtual" or guest operating system (OS) inside your main (host) OS
# 2. They both are virtual machine software suites for x86 and x64 computers
# 3. Both are free software
# 4. VMware Player is used for Windows OS and Oracle VirtualBox is used for only Linux OS
#
# ## Question 9: What are the 2 Linux Desktops?
#
# 1. KDE and GNOME
# 2. KDE and Windows
# 3. GNOME and LinuxGUI
# 4. None of the above
